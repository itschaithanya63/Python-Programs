# %%
class Student:
    def __init__(self,name,usn):
        self.name=name
        self.usn=usn
    def display(self):
        print("Student Name:",self.name)
        print("USN:",self.usn)

s1=Student("Anu","1AB23CS001")
s2=Student("Chaithanya","25BECS141")
s1.display()
s2.display()
# Out:
# Student Name: Anu
# USN: 1AB23CS001
# Student Name: Chaithanya
# USN: 25BECS141

# %%
class Employee:
    def __init__(self,name,ID):
        self.name=name
        self.ID=ID
    def display(self):
        print("Employee Name:",self.name)
        print("ID:",self.ID)

e1=Employee("Chayy","E1ZY")
e1.display()
# Out:
# Employee Name: Chayy
# ID: E1ZY

# %%
#Constructor Example
class Employee:
    def __init__(self):
        print("Constructor is called")
e1=Employee()
# Out:
# Constructor is called

# %%
#PROBLEM STATEMENT-CREATE A LIBRARY MANAGEMENT SYSTEM USING OOP CONCEPT TO STORE AND DISPLAY BOOK DETAILS
class Book:
    def __init__(self,title,author,price):
        self.title=title
        self.author=author
        self.price=price
    def display(self):
        print("Book Title:", self.title)
        print("Author:", self.author)
        print("Price :",self.price)

#creating objects
b1=Book("Python Programming","Guido",450)
b2=Book("Atomic Habits","James Clear",260)

#Display details
b1.display()
print("--------------------------")
b2.display()
# Out:
# Book Title: Python Programming
# Author: Guido
# Price : 450
# --------------------------
# Book Title: Atomic Habits
# Author: James Clear
# Price : 260

# %%
#PROBLEM STATEMENT-CREATE A BANK SYSTEM WITH DEPOSIT AND WITHDRAWAL OPERATIONS
class BankAccount:
    def __init__(self,name,balance):
        self.name=name
        self.balance=balance

    def deposit(self,amount):
        self.balance+=amount
        print(amount,"deposited successfully")

    def withdraw(self,amount):
        if amount<=self.balance:
            self.balance-=amount
            print(amount,"withdrawn succeessfully")
        else:
            print("Insufficient Balance")

    def display(self):
        print("Account Holder:",self.name)
        print("Balance :",self.balance)

#Object creation
b=BankAccount("Chay",10000)
b.display()
b.deposit(2000)
b.withdraw(5000)
b.display()
# Out:
# Account Holder: Chay
# Balance : 10000
# 2000 deposited successfully
# 5000 withdrawn succeessfully
# Account Holder: Chay
# Balance : 7000

# %%
#PROBLEM STATEMENT:Student Result Management System,calculate total marks and perecntage using OOP
class Student:
    
    def __init__(self,name,m1,m2,m3):
        self.name=name
        self.m1=m1
        self.m2=m2
        self.m3=m3
        
    def calculate(self):
       total=self.m1+self.m2+self.m3
       percentage=total/3

       print("Student Name:",self.name)
       print("Total Marks:",total)
       print("Percentage:",percentage)

s1=Student("Chay",85,90,88)
s1.calculate()
# Out:
# Student Name: Chay
# Total Marks: 263
# Percentage: 87.66666666666667
