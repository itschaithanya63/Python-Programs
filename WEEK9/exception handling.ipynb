# %%
try:
    a=int(input("Enter a :"))
    b=int(input("Enter b"))
    c=a/b;
    print("a/b=%d"%c)
except Exception :
    print("can't divide by zero")
except ValueError:
    print("Enter numbers only")
else: 
    print("code for else block")
#other code:
print("other part of the program")
# Out:
# Enter a : 21
# Enter b 3
# a/b=7
# code for else block
# other part of the program

# %%
try:
    a=int(input("Enter a :"))
    b=int(input("Enter b"))
    c=a/b;
    print("a/b=%d"%c)
except Zerodivisonerror :
    print("can't divide by zero")
except ValueError:
    print("Enter numbers only")
else: 
    print("code for else block")
finally:
    print("Imp code-always exceutes")
# Out:
# Enter a : 24
# Enter b 4
# a/b=6
# code for else block
# Imp code-always exceutes
